# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'da342396-84fe-4ea1-80e5-b8f25452f85b',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
pd.json_normalize(data['data'])
# Out:
#          id          name    symbol          slug  num_market_pairs  \
# 0         1       Bitcoin       BTC       bitcoin             12391
# 1      1027      Ethereum       ETH      ethereum             10834
# 2       825   Tether USDt      USDT        tether            149471
# 3        52           XRP       XRP           xrp              1711
# 4      1839           BNB       BNB           bnb              2760
# ...     ...           ...       ...           ...               ...
# 4995   2994  Bitcoin File      BIFI  bitcoin-file                 4
# 4996  34319   AgentFun.AI  AGENTFUN   agentfun-ai                 4
# 4997  12364      Youclout       YCT      youclout                 6
# 4998  11153       EmiSwap       ESW       emiswap                 8
# 4999  18210     Kyberdyne       KBD     kyberdyne                 5
#
#                     date_added  \
# 0     2010-07-13T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2015-02-25T00:00:00.000Z
# 3     2013-08-04T00:00:00.000Z
# 4     2017-07-25T00:00:00.000Z
# ...                        ...
# 4995  2018-07-28T00:00:00.000Z
# 4996  2024-11-29T11:31:38.000Z
# 4997  2021-10-06T01:06:32.000Z
# 4998  2021-08-03T00:00:00.000Z
# 4999  2022-02-21T06:07:50.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2     [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 3     [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 4     [marketplace, centralized-exchange, payments, ...           NaN
# ...                                                 ...           ...
# 4995                                                 []           NaN
# 4996                                 [cronos-ecosystem]  1.000000e+08
# 4997                              [bnb-chain-ecosystem]  1.000000e+09
# 4998            [ethereum-ecosystem, polygon-ecosystem]  2.000000e+08
# 4999   [collectibles-nfts, gaming, bnb-chain-ecosystem]           NaN
#
#       circulating_supply         total_supply  infinite_supply  platform  \
# 0           1.992635e+07             19926353            False       NaN
# 1           1.207034e+08     120703418.472637             True       NaN
# 2           1.734405e+11  178071777667.487244             True       NaN
# 3           5.977724e+10          99985800180            False       NaN
# 4           1.391859e+08         139185875.45            False       NaN
# ...                  ...                  ...              ...       ...
# 4995        0.000000e+00          21050000000            False       NaN
# 4996        0.000000e+00      99999551.604098            False       NaN
# 4997        0.000000e+00           1000000000            False       NaN
# 4998        0.000000e+00          42946444.51            False       NaN
# 4999        0.000000e+00                    0            False       NaN
#
#       cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0            1                               NaN                       NaN
# 1            2                               NaN                       NaN
# 2            3                               NaN                       NaN
# 3            4                               NaN                       NaN
# 4            5                               NaN                       NaN
# ...        ...                               ...                       ...
# 4995      4996                               NaN                       NaN
# 4996      4997                      1.000000e+08              2.059564e+08
# 4997      4998                      1.666667e+07              6.042411e+02
# 4998      4999                      4.294644e+07              5.747279e+04
# 4999      5000                               NaN                       NaN
#
#       tvl_ratio              last_updated  quote.USD.price  \
# 0           NaN  2025-09-26T07:28:00.000Z    109455.525729
# 1           NaN  2025-09-26T07:28:00.000Z      3937.234297
# 2           NaN  2025-09-26T07:27:00.000Z         1.000644
# 3           NaN  2025-09-26T07:28:00.000Z         2.764208
# 4           NaN  2025-09-26T07:28:00.000Z       948.293610
# ...         ...                       ...              ...
# 4995        NaN  2025-09-26T07:27:00.000Z         0.000200
# 4996        NaN  2025-09-26T07:27:00.000Z         2.059564
# 4997        NaN  2025-09-26T07:28:00.000Z         0.000036
# 4998        NaN  2025-09-26T07:28:00.000Z         0.001338
# 4999        NaN  2025-09-26T07:27:00.000Z         0.000086
#
#       quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0             7.080623e+10                      38.0263
# 1             6.043809e+10                      45.2272
# 2             1.857640e+11                      33.1125
# 3             8.862170e+09                      31.3779
# 4             4.593076e+09                      27.7177
# ...                    ...                          ...
# 4995          1.676067e+04                       6.0055
# 4996          1.665954e+04                     398.1011
# 4997          1.670602e+04                      -2.5457
# 4998          1.664838e+04                       0.0655
# 4999          1.665038e+04                      -4.4349
#
#       quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                       -0.162540                     -2.149820
# 1                       -0.298348                     -1.846930
# 2                        0.025749                      0.037437
# 3                       -0.182625                     -3.190436
# 4                        0.357377                     -4.366741
# ...                           ...                           ...
# 4995                     0.173645                     -1.881205
# 4996                     1.827985                      5.120578
# 4997                    -1.592963                     -6.780972
# 4998                     0.038198                      0.049287
# 4999                     0.038318                      0.002475
#
#       quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                       -6.384470                     -1.208100
# 1                      -13.230844                    -13.837932
# 2                        0.024975                      0.076421
# 3                       -8.992976                     -7.559623
# 4                       -4.907659                     10.565646
# ...                           ...                           ...
# 4995                   -13.081733                     -4.387774
# 4996                   -13.170603                    -20.762487
# 4997                    -9.947138                      1.366218
# 4998                     0.025799                      0.087562
# 4999                     2.611780                      6.233506
#
#       quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                        -8.135298                      1.841125
# 1                         1.019922                     62.168060
# 2                         0.058471                      0.026069
# 3                       -15.749225                     26.230838
# 4                        11.346341                     46.596497
# ...                            ...                           ...
# 4995                     -8.636813                    -16.931381
# 4996                    -18.667601                     43.053845
# 4997                     33.264106                      8.112289
# 4998                      0.060444                      0.043354
# 4999                    -29.649994                    -34.546129
#
#       quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0             2.181049e+12                         58.0724
# 1             4.752376e+11                         12.6608
# 2             1.735522e+11                          4.6236
# 3             1.652367e+11                          4.3996
# 4             1.319891e+11                          3.5143
# ...                    ...                             ...
# 4995          0.000000e+00                          0.0000
# 4996          0.000000e+00                          0.0000
# 4997          0.000000e+00                          0.0000
# 4998          0.000000e+00                          0.0000
# 4999          0.000000e+00                          0.0000
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                           2.298566e+12            NaN
# 1                           4.752376e+11            NaN
# 2                           1.781864e+11            NaN
# 3                           2.764208e+11            NaN
# 4                           1.319891e+11            NaN
# ...                                  ...            ...
# 4995                        4.208511e+06            NaN
# 4996                        2.059564e+08            NaN
# 4997                        3.625447e+04            NaN
# 4998                        2.676487e+05        36460.0
# 4999                        0.000000e+00            NaN
#
#         quote.USD.last_updated  platform.id            platform.name  \
# 0     2025-09-26T07:28:00.000Z          NaN                      NaN
# 1     2025-09-26T07:28:00.000Z          NaN                      NaN
# 2     2025-09-26T07:27:00.000Z       1027.0                 Ethereum
# 3     2025-09-26T07:28:00.000Z          NaN                      NaN
# 4     2025-09-26T07:28:00.000Z          NaN                      NaN
# ...                        ...          ...                      ...
# 4995  2025-09-26T07:27:00.000Z          NaN                      NaN
# 4996  2025-09-26T07:27:00.000Z       3635.0     Cronos zkEVM Mainnet
# 4997  2025-09-26T07:28:00.000Z       1839.0  BNB Smart Chain (BEP20)
# 4998  2025-09-26T07:28:00.000Z       1027.0                 Ethereum
# 4999  2025-09-26T07:27:00.000Z       1839.0  BNB Smart Chain (BEP20)
#
#      platform.symbol platform.slug                      platform.token_address
# 0                NaN           NaN                                         NaN
# 1                NaN           NaN                                         NaN
# 2                ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3                NaN           NaN                                         NaN
# 4                NaN           NaN                                         NaN
# ...              ...           ...                                         ...
# 4995             NaN           NaN                                         NaN
# 4996             CRO        cronos  0x18d40Bd95e34d1a4fcaf9027Db11F6988e5B860A
# 4997             BNB           bnb  0x23e3981052d5280c658e5e18d814fa9582bfbc9e
# 4998             ETH      ethereum  0x5a75a093747b72a0e14056352751edf03518031d
# 4999             BNB           bnb  0xe3E3F8218562a7c9b594BEF2946Ec72f1b043ae8
#
# [5000 rows x 36 columns]

# %%
--NotebookApp.allow_origin='*'
# Out:
#   Cell In[18], line 1
#     --NotebookApp.allow_origin='*'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?
